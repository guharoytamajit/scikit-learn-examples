# %%
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=42)
tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train, y_train)

print('Accuracy on the training subset: {:.3f}'.format(tree.score(X_train, y_train)))
print('Accuracy on the test subset: {:.3f}'.format(tree.score(X_test, y_test)))
# Out:
# Accuracy on the training subset: 1.000
# Accuracy on the test subset: 0.937

# %%
tree = DecisionTreeClassifier(max_depth=4, random_state=0)
tree.fit(X_train, y_train)

print('Accuracy on the training subset: {:.3f}'.format(tree.score(X_train, y_train)))
print('Accuracy on the test subset: {:.3f}'.format(tree.score(X_test, y_test)))
# Out:
# Accuracy on the training subset: 0.988
# Accuracy on the test subset: 0.951

# %%
import graphviz
from sklearn.tree import export_graphviz


export_graphviz(tree, out_file='cancertree.dot', class_names=['malignant', 'benign'], feature_names=cancer.feature_names,
               impurity=False, filled=True)
#dot -Tpng mytree.dot > mytree.png

# %%
import numpy as np
n_features = cancer.data.shape[1] #30
plt.barh(range(n_features), tree.feature_importances_, align='center')
plt.yticks(np.arange(n_features), cancer.feature_names)
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.show()
for i in range(n_features):
    print(cancer.feature_names[i],"=",tree.feature_importances_[i]);
# Out:
# mean radius = 0.0
# mean texture = 0.00752596989612
# mean perimeter = 0.0
# mean area = 0.0
# mean smoothness = 0.00903116387534
# mean compactness = 0.0
# mean concavity = 0.00752596989612
# mean concave points = 0.0
# mean symmetry = 0.0
# mean fractal dimension = 0.0
# radius error = 0.00975731470923
# texture error = 0.0463096931067
# perimeter error = 0.0
# area error = 0.00238744731808
# smoothness error = 0.00231135337966
# compactness error = 0.0
# concavity error = 0.0
# concave points error = 0.0
# symmetry error = 0.0
# fractal dimension error = 0.00668975101877
# worst radius = 0.695463218147
# worst texture = 0.0538321064137
# worst perimeter = 0.0
# worst area = 0.013546745813
# worst smoothness = 0.0
# worst compactness = 0.0
# worst concavity = 0.0174031187087
# worst concave points = 0.116843570986
# worst symmetry = 0.0113725767319
# worst fractal dimension = 0.0

# %% [markdown]
# Advantages of Decision Trees:
# easy to view and understand
# no need to pre-process, normalize, scale, and/or standardize features
# Paramaters to work with:
# max_depth
# min_samples_leaf, max_samples_leaf
# max_leaf_nodes
# etc.
# Main Disadvantages:
# tendency to overfit
# poor generalization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=(4,3)
plt.rcParams['figure.dpi']=150

# %%
s=pd.Series(['tamajit',1,True,10],index=[4,5,6,9])

# %%
x=pd.Series({'a':'apple','b':'ball','c':'cat'})

# %%
y=pd.Series([34,67,22,74,11,94])

# %%
y[y>50]=100
z=y

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
football['matches']=football['wins']+football['losses']
football.to_excel('football.xlsx', index=False)

# %%
r=np.arange(0,10,0.5)

plt.plot(r,3*r+4,color='red',marker='o',linestyle='none')
plt.plot(r,np.sin(r),label="y=sin(x)",linestyle='--')
plt.plot(r,np.cos(r),'g+--',linewidth=5)
plt.xlabel('x label')
plt.ylabel('y label')
plt.ylim(-1,20)
plt.legend()

# %%
rand=np.random.normal(size=100)
plt.hist(rand)
# Out:
# (array([  4.,  12.,   8.,  20.,  12.,  17.,  13.,   6.,   4.,   4.]),
#  array([-1.7200302 , -1.33407485, -0.9481195 , -0.56216415, -0.1762088 ,
#          0.20974655,  0.5957019 ,  0.98165725,  1.3676126 ,  1.75356795,
#          2.1395233 ]),
#  <a list of 10 Patch objects>)
